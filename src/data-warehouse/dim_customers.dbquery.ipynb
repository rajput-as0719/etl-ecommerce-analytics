-- %%
create or replace table ecommerce_analytics.data_warehouse.dim_customers (
 customer_id int,
 custmoer_name string
)
Insert into ecommerce_analytics.data_warehouse.dim_customers
select
 customer_id,
 customer_name
 from
 batch_1.data1.customers;

select * from ecommerce_analytics.data_warehouse.dim_customers;

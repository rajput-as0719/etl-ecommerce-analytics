-- %%
create or replace table ecommerce_analytics.data_warehouse.dim_products (
  product_id string,
  product_name string
);
Insert into ecommerce_analytics.data_warehouse.dim_products
select
  distinct product_id,
  product_name
from
  batch_1.data1.sales_order;

select * from ecommerce_analytics.data_warehouse.dim_products;
